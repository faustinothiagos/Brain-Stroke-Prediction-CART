# %% [markdown]
# <a id="section_CART"></a>
# ## Árvores de classificação: fazendo previsão sobre uma variável categórica

# %%
# Importandos as bibliotecas de análise de dados
import pandas as pd
import numpy as np
import random as rnd

# %%
# Importando as bibliotecas de visualização
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importando o conjunto de dados, que usamos em nosso projeto 
df = pd.read_csv("../DataSet/full_data.csv")
display(df.head(6))
print()
pd.DataFrame(df.dtypes,columns=['dtypes'])
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
# 5    Male  74.0             1              1          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1
# ...

# %%
# Análizando como o conjunto de dados é composto:
df.groupby(['hypertension']).count()
# Out:
#               gender   age  heart_disease  ever_married  work_type  \
# hypertension
# 0               4502  4502           4502          4502       4502
# 1                479   479            479           479        479
#
#               Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# hypertension
# 0                       4502               4502  4502            4502    4502
# 1                        479                479   479             479     479
